# %%
import h5py

path = r"D:\DACN\dbl_alphapepdeep\_lt\data\traintest_hcd.hdf5"

f = h5py.File(path, "r")
for key in list(f.keys()):
    print(key)
# Out:
# collision_energy
# collision_energy_aligned
# collision_energy_aligned_normed
# intensities_raw
# masses_pred
# masses_raw
# method
# precursor_charge_onehot
# rawfile
# reverse
# scan_number
# score
# sequence_integer
# sequence_onehot

# %%
intensity = f["intensities_raw"][:]
charge = f["precursor_charge_onehot"][:100]
squence = f["sequence_integer"][:100]
collision_energy = f["collision_energy"][:100]
instrument = f["score"][:100]

# %%
squence = f["sequence_integer"][:]

# %%
charge = f["precursor_charge_onehot"][:]

# %%
intensity = f["intensities_raw"][:174]

# %%
print(intensity)
# Out:
# [[ 0.03333019  0.          0.         ... -1.         -1.
#   -1.        ]
#  [ 0.29109679  0.         -1.         ... -1.         -1.
#   -1.        ]
#  [ 0.07164449  0.         -1.         ... -1.         -1.
#   -1.        ]
#  ...
#  [ 0.50206691  0.         -1.         ... -1.         -1.
#   -1.        ]
#  [ 0.13580419  0.          0.         ... -1.         -1.
#   -1.        ]
#  [ 0.69987786  0.          0.         ... -1.         -1.
#   -1.        ]]
